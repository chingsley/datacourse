# %%
# %matplotlib inline
import matplotlib
import seaborn as sns
sns.set()
matplotlib.rcParams['figure.dpi'] = 144

# %%
from static_grader import grader

# %% [markdown]
# # DW Miniproject
# ## Introduction
#
# The objective of this miniproject is to exercise your ability to wrangle tabular data set and aggregate large data sets into meaningful summary statistics. We'll work with the same medical data used in the `pw` miniproject but leverage the power of Pandas to more efficiently represent and act on our data.

# %% [markdown]
# ## Downloading the data
#
# We first need to download the data we'll be using from Amazon S3:

# %%
# !mkdir dw-data
# !wget http://dataincubator-wqu.s3.amazonaws.com/dwdata/201701scripts_sample.csv.gz -nc -P ./dw-data/
# !wget http://dataincubator-wqu.s3.amazonaws.com/dwdata/201606scripts_sample.csv.gz -nc -P ./dw-data/
# !wget http://dataincubator-wqu.s3.amazonaws.com/dwdata/practices.csv.gz -nc -P ./dw-data/
# !wget http://dataincubator-wqu.s3.amazonaws.com/dwdata/chem.csv.gz -nc -P ./dw-data/
# Out:
# mkdir: cannot create directory ‘dw-data’: File exists
# File ‘./dw-data/201701scripts_sample.csv.gz’ already there; not retrieving.
#
# File ‘./dw-data/201606scripts_sample.csv.gz’ already there; not retrieving.
#
# File ‘./dw-data/practices.csv.gz’ already there; not retrieving.
#
# File ‘./dw-data/chem.csv.gz’ already there; not retrieving.

# %% [markdown]
# ## Loading the data
#
# Similar to the `PW` miniproject, the first step is to read in the data. The data files are stored as compressed CSV files. You can load the data into a Pandas DataFrame by making use of the `gzip` package to decompress the files and Panda's `read_csv` methods to parse the data into a DataFrame. You may want to check the Pandas documentation for parsing [CSV](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) files for reference.
#
# For a description of the data set please, refer to the [PW miniproject](./pw.ipynb). **Note that all questions make use of the 2017 data only, except for Question 5 which makes use of both the 2017 and 2016 data.**

# %%
import pandas as pd
import numpy as np
import gzip

# %%
scripts = pd.read_csv('dw-data/201701scripts_sample.csv.gz')
scripts.head()
# Out:
#   practice   bnf_code                              bnf_name  items   nic  \
# 0   N85639  0106020C0                 Bisacodyl_Tab E/C 5mg      1  0.39
# 1   N85639  0106040M0      Movicol Plain_Paed Pdr Sach 6.9g      1  4.38
# 2   N85639  0301011R0    Salbutamol_Inha 100mcg (200 D) CFF      1  1.50
# 3   N85639  0304010G0  Chlorphenamine Mal_Oral Soln 2mg/5ml      1  2.62
# 4   N85639  0401020K0                      Diazepam_Tab 2mg      1  0.16
#
#    act_cost  quantity
# 0      0.47        12
# 1      4.07        30
# 2      1.40         1
# 3      2.44       150
# 4      0.26         6

# %%
col_names=[ 'code', 'name', 'addr_1', 'addr_2', 'borough', 'village', 'post_code']

with gzip.open('./dw-data/practices.csv.gz', 'rb') as f:
    practices = pd.read_csv(f, names=col_names)
    
practices.head()
# Out:
#      code                        name                   addr_1         addr_2  \
# 0  A81001         THE DENSHAM SURGERY        THE HEALTH CENTRE  LAWSON STREET
# 1  A81002  QUEENS PARK MEDICAL CENTRE  QUEENS PARK MEDICAL CTR  FARRER STREET
# 2  A81003   VICTORIA MEDICAL PRACTICE        THE HEALTH CENTRE  VICTORIA ROAD
# 3  A81004      WOODLANDS ROAD SURGERY         6 WOODLANDS ROAD            NaN
# 4  A81005          SPRINGWOOD SURGERY       SPRINGWOOD SURGERY   RECTORY LANE
#
#             borough    village post_code
# 0  STOCKTON ON TEES  CLEVELAND  TS18 1HU
# 1  STOCKTON ON TEES  CLEVELAND  TS18 2AW
# 2        HARTLEPOOL  CLEVELAND  TS26 8DB
# 3     MIDDLESBROUGH  CLEVELAND   TS1 3BE
# 4       GUISBOROUGH        NaN  TS14 7DJ

# %%
with gzip.open('./dw-data/chem.csv.gz', 'rb') as f:
    chem = pd.read_csv(f)
    
chem.head()
# Out:
#     CHEM SUB                                NAME
# 0  0101010A0                     Alexitol Sodium
# 1  0101010B0                          Almasilate
# 2  0101010C0                 Aluminium Hydroxide
# 3  0101010D0  Aluminium Hydroxide With Magnesium
# 4  0101010E0                        Hydrotalcite

# %% [markdown]
# Now that we've loaded in the data, let's first replicate our results from the `PW` miniproject. Note that we are now working with a larger data set so the answers will be different than in the `PW` miniproject even if the analysis is the same.

# %% [markdown]
# ## Question 1: summary_statistics
#
# In the `PW` miniproject we first calculated the total, mean, standard deviation, and quartile statistics of the `'items'`, `'quantity'`', `'nic'`, and `'act_cost'` fields. To do this we had to write some functions to calculate the statistics and apply the functions to our data structure. The DataFrame has a `describe` method that will calculate most (not all) of these things for us.
#
# Submit the summary statistics to the grader as a list of tuples: [('act_cost', (total, mean, std, q25, median, q75)), ...]

# %%
# print(scripts['items'].sum())
desc = scripts['items'].describe()
# print(desc)
# print(desc['mean'] * desc['count'])
# print(desc['75%'])

result = []

for field in ['items', 'quantity', 'nic', 'act_cost']:
    desc = scripts[field].describe()
    
    total = scripts[field].sum()
    mean = desc['mean']
    std = desc['std']
    q25 = desc['25%']
    median = desc['50%']
    q75 = desc['75%']
    result.append((field, (total, mean, std, q25, median, q75)))

# %%
result
# Out:
# [('items', (8888304, 9.133135976111625, 29.204198282803603, 1.0, 2.0, 6.0)),
#  ('quantity',
#   (721457006, 741.3298348837282, 3665.426958467915, 28.0, 100.0, 350.0)),
#  ('nic',
#   (71100424.84000002, 73.05891517920908, 188.070256906825, 7.8, 22.64, 65.0)),
#  ('act_cost',
#   (66164096.11999999,
#    67.98661326170655,
#    174.40170332301963,
#    7.33,
#    21.22,
#    60.67))]

# %%
summary_stats = result
summary_stats
# Out:
# [('items', (8888304, 9.133135976111625, 29.204198282803603, 1.0, 2.0, 6.0)),
#  ('quantity',
#   (721457006, 741.3298348837282, 3665.426958467915, 28.0, 100.0, 350.0)),
#  ('nic',
#   (71100424.84000002, 73.05891517920908, 188.070256906825, 7.8, 22.64, 65.0)),
#  ('act_cost',
#   (66164096.11999999,
#    67.98661326170655,
#    174.40170332301963,
#    7.33,
#    21.22,
#    60.67))]

# %%
grader.score.dw__summary_statistics(summary_stats)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# ## Question 2: most_common_item
#
# We can also easily compute summary statistics on groups within the data. In the `pw` miniproject we had to explicitly construct the groups based on the values of a particular field. Pandas will handle that for us via the `groupby` method. This process is [detailed in the Pandas documentation](https://pandas.pydata.org/pandas-docs/stable/groupby.html).
#
# Use `groupby` to calculate the total number of items dispensed for each `'bnf_name'`. Find the item with the highest total and return the result as `[(bnf_name, total)]`.

# %%
groupby_bnfname = scripts.groupby('bnf_name')
total_items_for_each_bnfname = groupby_bnfname['items'].sum()
max_item = total_items_for_each_bnfname.max()
bnfname_with_max_item = total_items_for_each_bnfname.idxmax()
item_with_highest_total = [(bnfname_with_max_item, max_item)]
print(item_with_highest_total)
# Out:
# [('Omeprazole_Cap E/C 20mg', 218583)]

# %%
most_common_item = item_with_highest_total

# %%
grader.score.dw__most_common_item(most_common_item)
# Out:
# ==================
# Error!
# You have been rate limited for exceeding the limit of 1 per 1 second.
# Please slow down your submission rate.
# ==================

# %% [markdown]
# ## Question 3: items_by_region
#
# Now let's find the most common item by post code. The post code information is in the `practices` DataFrame, and we'll need to `merge` it into the `scripts` DataFrame. Pandas provides [extensive documentation](https://pandas.pydata.org/pandas-docs/stable/merging.html) with diagrammed examples on different methods and approaches for joining data. The `merge` method is only one of many possible options.
#
# Return your results as a list of tuples `(post code, item name, amount dispensed as % of total)`. Sort your results ascending alphabetically by post code and take only results from the first 100 post codes.
#
# **NOTE:** Some practices have multiple postal codes associated with them. Use the alphabetically first postal code. Note some postal codes may have multiple `'bnf_name'` with the same prescription rate for the maximum. In this case, take the alphabetically first `'bnf_name'` (as in the PW miniproject).

# %%
# merged_df = yelp_df.merge(census, on=['state', 'city'], how='left')
scripts.head()
# practices.head()
# joined = scripts.merge(practices, on=['practice', 'code'])
joined = scripts.set_index('practice').join(practices.set_index('code'))
print(joined.shape)
print(scripts.shape)
print(practices.shape)
# joined.head()
# Out:
# (1134693, 12)
# (973193, 7)
# (12020, 7)

# %%
by_pc = joined.groupby('post_code')
by_pc['items'].sum()
# Out:
# post_code
# B11 4BW     22731
# B12 9LP     23236
# B18 7AL     20508
# B21 9RY     31027
# B23 6DJ     28011
#             ...
# WS7 0EW     14122
# WS9 8AJ     24483
# WV13 2DR    36381
# YO11 1UB    28507
# YO16 4LZ    53847
# Name: items, Length: 289, dtype: int64

# %%
by_pc_and_bnfname = joined.groupby(['post_code', 'bnf_name']).last()
by_pc_and_bnfname.head()
# Out:
#                                                      bnf_code  items    nic  \
# post_code bnf_name
# B11 4BW   3m Health Care_Cavilon Durable Barrier C  238031080      1   3.98
#           3m Health Care_Cavilon No Sting Barrier   238031080      1   5.98
#           Abasaglar KwikPen_100u/ml 3ml Pf Pen      0601012V0      2  70.56
#           Abidec_Dps                                090607000     17  56.61
#           Able Spacer + Sml/Med Mask                210102301      1   7.16
#
#                                                     act_cost  quantity  \
# post_code bnf_name
# B11 4BW   3m Health Care_Cavilon Durable Barrier C      3.70         1
#           3m Health Care_Cavilon No Sting Barrier       5.55         1
#           Abasaglar KwikPen_100u/ml 3ml Pf Pen         65.35        10
#           Abidec_Dps                                   52.62       425
#           Able Spacer + Sml/Med Mask                    6.64         1
#
#                                                                                name  \
# post_code bnf_name
# B11 4BW   3m Health Care_Cavilon Durable Barrier C  THE HILL GENERAL PRACTICE & UCC
#           3m Health Care_Cavilon No Sting Barrier   THE HILL GENERAL PRACTICE & UCC
#           Abasaglar KwikPen_100u/ml 3ml Pf Pen      THE HILL GENERAL PRACTICE & UCC
#           Abidec_Dps                                THE HILL GENERAL PRACTICE & UCC
#           Able Spacer + Sml/Med Mask                                OAKWOOD SURGERY
#
#                                                                       addr_1  \
# post_code bnf_name
# B11 4BW   3m Health Care_Cavilon Durable Barrier C        856 STRATFORD ROAD
#           3m Health Care_Cavilon No Sting Barrier         856 STRATFORD ROAD
#           Abasaglar KwikPen_100u/ml 3ml Pf Pen            856 STRATFORD ROAD
#           Abidec_Dps                                      856 STRATFORD ROAD
#           Able Spacer + Sml/Med Mask                SPARKHILL PRIM. CARE CTR
#
#                                                                 addr_2  \
# post_code bnf_name
# B11 4BW   3m Health Care_Cavilon Durable Barrier C           SPARKHILL
#           3m Health Care_Cavilon No Sting Barrier            SPARKHILL
#           Abasaglar KwikPen_100u/ml 3ml Pf Pen               SPARKHILL
#           Abidec_Dps                                         SPARKHILL
#           Able Spacer + Sml/Med Mask                856 STRATFORD ROAD
#
#                                                        borough        village
# post_code bnf_name
# B11 4BW   3m Health Care_Cavilon Durable Barrier C  BIRMINGHAM  WEST MIDLANDS
#           3m Health Care_Cavilon No Sting Barrier   BIRMINGHAM  WEST MIDLANDS
#           Abasaglar KwikPen_100u/ml 3ml Pf Pen      BIRMINGHAM  WEST MIDLANDS
#           Abidec_Dps                                BIRMINGHAM  WEST MIDLANDS
#           Able Spacer + Sml/Med Mask                BIRMINGHAM            NaN

# %%
practices['code'].nunique()
# Out:
# 10843

# %%
practices[practices['code'] == 'A81008']
# Out:
#          code                 name                     addr_1  \
# 7      A81008  ALBERT HOUSE CLINIC  LOW GRANGE HEALTH VILLAGE
# 11414  A81008  ALBERT HOUSE CLINIC  SOUTH GRANGE MEDICAL CTR.
#
#                   addr_2        borough    village post_code
# 7          NORMANBY ROAD  MIDDLESBROUGH  CLEVELAND   TS6 6TD
# 11414  TRUNK ROAD  ESTON  MIDDLESBROUGH  CLEVELAND   TS6 9QG

# %%
by_code = practices.sort_values('post_code').groupby('code')
by_code.groups
# Out:
# {'A81001': Int64Index([0, 9905], dtype='int64'),
#  'A81002': Int64Index([1], dtype='int64'),
#  'A81003': Int64Index([11057, 2], dtype='int64'),
#  'A81004': Int64Index([3, 11915], dtype='int64'),
#  'A81005': Int64Index([4], dtype='int64'),
#  'A81006': Int64Index([5, 11058], dtype='int64'),
#  'A81007': Int64Index([6], dtype='int64'),
#  'A81008': Int64Index([7, 11414], dtype='int64'),
#  'A81009': Int64Index([8], dtype='int64'),
#  'A81011': Int64Index([9], dtype='int64'),
#  'A81012': Int64Index([10], dtype='int64'),
#  'A81013': Int64Index([11], dtype='int64'),
#  'A81014': Int64Index([12], dtype='int64'),
#  'A81015': Int64Index([13], dtype='int64'),
#  'A81016': Int64Index([14], dtype='int64'),
#  'A81017': Int64Index([15], dtype='int64'),
#  'A81018': Int64Index([16], dtype='int64'),
#  'B81689': Int64Index([7243], dtype='int64'),
#  'B81690': Int64Index([7257], dtype='int64'),
#  'B81692': Int64Index([7316], dtype='int64'),
#  'B81693': Int64Index([7383], dtype='int64'),
#  'B81697': Int64Index([7422], dtype='int64'),
#  'B82001': Int64Index([529], dtype='int64'),
#  'B82002': Int64Index([530], dtype='int64'),
#  'B82003': Int64Index([10679, 531], dtype='int64'),
#  'B82004': Int64Index([532], dtype='int64'),
#  'B82005': Int64Index([533], dtype='int64'),
#  'B82006': Int64Index([10680, 534], dtype='int64'),
#  'B82007': Int64Index([535], dtype='int64'),
#  'B82008': Int64Index([536], dtype='int64'),
#  'B82010': Int64Index([537], dtype='int64'),
#  'B82011': Int64Index([538], dtype='int64'),
#  'B82012': Int64Index([539], dtype='int64'),
#  'B82013': Int64Index([540], dtype='int64'),
#  'B82014': Int64Index([541], dtype='int64'),
#  'B82016': Int64Index([542], dtype='int64'),
#  'B82017': Int64Index([543], dtype='int64'),
#  'B82018': Int64Index([544], dtype='int64'),
#  'B82019': Int64Index([11790, 545], dtype='int64'),
#  'B82020': Int64Index([11417, 546], dtype='int64'),
#  'B82021': Int64Index([547], dtype='int64'),
#  'B82022': Int64Index([548], dtype='int64'),
#  'B82023': Int64Index([549], dtype='int64'),
#  'B82024': Int64Index([550], dtype='int64'),
#  'B82025': Int64Index([551], dtype='int64'),
#  'B82026': Int64Index([552], dtype='int64'),
#  'B82027': Int64Index([553], dtype='int64'),
#  'B82028': Int64Index([554], dtype='int64'),
#  'B82029': Int64Index([555], dtype='int64'),
#  'B82030': Int64Index([556], dtype='int64'),
#  'B82031': Int64Index([557], dtype='int64'),
#  'B82032': Int64Index([558], dtype='int64'),
#  'B82033': Int64Index([559], dtype='int64'),
#  'B82034': Int64Index([10145, 10827, 560], dtype='int64'),
#  'B82035': Int64Index([561], dtype='int64'),
#  'B82036': Int64Index([562], dtype='int64'),
#  'B82037': Int64Index([563], dtype='int64'),
#  'B82038': Int64Index([564], dtype='int64'),
#  'B82041': Int64Index([565], dtype='int64'),
#  'B82042': Int64Index([566], dtype='int64'),
#  'B82044': Int64Index([567], dtype='int64'),
#  'B82045': Int64Index([568], dtype='int64'),
#  'B82046': Int64Index([569], dtype='int64'),
#  'B82047': Int64Index([570], dtype='int64'),
#  'B82049': Int64Index([571], dtype='int64'),
#  'B82050': Int64Index([572], dtype='int64'),
#  'B82053': Int64Index([573], dtype='int64'),
#  'B82054': Int64Index([574], dtype='int64'),
#  'B82057': Int64Index([575], dtype='int64'),
#  'B82059': Int64Index([576, 10146], dtype='int64'),
#  'B82060': Int64Index([577], dtype='int64'),
#  'B82061': Int64Index([578], dtype='int64'),
#  'B82062': Int64Index([579], dtype='int64'),
#  'B82063': Int64Index([580], dtype='int64'),
#  'B82064': Int64Index([581], dtype='int64'),
#  'B82066': Int64Index([582], dtype='int64'),
#  'B82067': Int64Index([583], dtype='int64'),
#  'B82068': Int64Index([584], dtype='int64'),
#  'B82069': Int64Index([585], dtype='int64'),
#  'B82071': Int64Index([586], dtype='int64'),
#  'B82072': Int64Index([587], dtype='int64'),
#  'B82073': Int64Index([588], dtype='int64'),
#  'B82074': Int64Index([589], dtype='int64'),
#  'B82075': Int64Index([590], dtype='int64'),
#  'B82077': Int64Index([591], dtype='int64'),
#  'B82078': Int64Index([592], dtype='int64'),
#  'B82079': Int64Index([593], dtype='int64'),
#  'B82080': Int64Index([594], dtype='int64'),
#  'B82081': Int64Index([595], dtype='int64'),
#  'B82083': Int64Index([596], dtype='int64'),
#  'B82086': Int64Index([597], dtype='int64'),
#  'B82088': Int64Index([598], dtype='int64'),
#  'B82091': Int64Index([599], dtype='int64'),
#  'B82092': Int64Index([600], dtype='int64'),
#  'B82095': Int64Index([601], dtype='int64'),
#  'B82097': Int64Index([602], dtype='int64'),
#  'B82098': Int64Index([603], dtype='int64'),
#  'B82099': Int64Index([9909], dtype='int64'),
#  'B82100': Int64Index([604], dtype='int64'),
#  'B82101': Int64Index([605], dtype='int64'),
#  'B82103': Int64Index([606], dtype='int64'),
#  'B82104': Int64Index([607], dtype='int64'),
#  'B82105': Int64Index([608], dtype='int64'),
#  'B82106': Int64Index([7302], dtype='int64'),
#  'B82609': Int64Index([609], dtype='int64'),
#  'B82611': Int64Index([610], dtype='int64'),
#  'B82619': Int64Index([611], dtype='int64'),
#  'B82622': Int64Index([612], dtype='int64'),
#  'B82628': Int64Index([613], dtype='int64'),
#  'B82634': Int64Index([7169], dtype='int64'),
#  'B82635': Int64Index([7170], dtype='int64'),
#  'B82636': Int64Index([7239], dtype='int64'),
#  'B82638': Int64Index([7247], dtype='int64'),
#  'B82640': Int64Index([9964], dtype='int64'),
#  'B83002': Int64Index([614, 10681], dtype='int64'),
#  'B83005': Int64Index([615], dtype='int64'),
#  'B83006': Int64Index([616], dtype='int64'),
#  'B83007': Int64Index([617], dtype='int64'),
#  'B83008': Int64Index([618], dtype='int64'),
#  'B83009': Int64Index([619], dtype='int64'),
#  'B83010': Int64Index([620], dtype='int64'),
#  'B83011': Int64Index([10682, 621, 10551], dtype='int64'),
#  'B83012': Int64Index([622], dtype='int64'),
#  'B83013': Int64Index([623], dtype='int64'),
#  'B83014': Int64Index([624], dtype='int64'),
#  'B83015': Int64Index([625], dtype='int64'),
#  'B83016': Int64Index([626], dtype='int64'),
#  'B83017': Int64Index([627], dtype='int64'),
#  'B83018': Int64Index([628], dtype='int64'),
#  'B83019': Int64Index([629], dtype='int64'),
#  'B83020': Int64Index([630], dtype='int64'),
#  'B83021': Int64Index([631], dtype='int64'),
#  'B83022': Int64Index([632], dtype='int64'),
#  'B83023': Int64Index([633, 10147], dtype='int64'),
#  'B83025': Int64Index([634], dtype='int64'),
#  'B83026': Int64Index([635], dtype='int64'),
#  'B83027': Int64Index([636], dtype='int64'),
#  'B83028': Int64Index([637], dtype='int64'),
#  'B83029': Int64Index([638], dtype='int64'),
#  'B83030': Int64Index([639], dtype='int64'),
#  'B83031': Int64Index([640], dtype='int64'),
#  'B83032': Int64Index([641], dtype='int64'),
#  'B83033': Int64Index([11174, 642], dtype='int64'),
#  'B84003': Int64Index([689], dtype='int64'),
#  'B84004': Int64Index([690], dtype='int64'),
#  'B84005': Int64Index([691], dtype='int64'),
#  'B84006': Int64Index([692], dtype='int64'),
#  'B84007': Int64Index([693], dtype='int64'),
#  'B84008': Int64Index([694], dtype='int64'),
#  'B84009': Int64Index([695], dtype='int64'),
#  'B84010': Int64Index([696], dtype='int64'),
#  'B84011': Int64Index([697], dtype='int64'),
#  'B84012': Int64Index([698], dtype='int64'),
#  'B84013': Int64Index([699], dtype='int64'),
#  'B84014': Int64Index([11177, 700], dtype='int64'),
#  'B84016': Int64Index([701], dtype='int64'),
#  'B84017': Int64Index([702], dtype='int64'),
#  'B84019': Int64Index([703], dtype='int64'),
#  'B84021': Int64Index([704], dtype='int64'),
#  'B84610': Int64Index([705], dtype='int64'),
#  'B84612': Int64Index([706], dtype='int64'),
#  'B84613': Int64Index([707, 11505], dtype='int64'),
#  'B84615': Int64Index([708], dtype='int64'),
#  'B84618': Int64Index([709], dtype='int64'),
#  'B84623': Int64Index([710], dtype='int64'),
#  'B85001': Int64Index([711], dtype='int64'),
#  'B85002': Int64Index([712], dtype='int64'),
#  'B85004': Int64Index([713], dtype='int64'),
#  'B85005': Int64Index([714], dtype='int64'),
#  'B85006': Int64Index([715], dtype='int64'),
#  'B85008': Int64Index([716], dtype='int64'),
#  'B85009': Int64Index([717], dtype='int64'),
#  'B85010': Int64Index([718], dtype='int64'),
#  'B85011': Int64Index([719, 10552], dtype='int64'),
#  'B85012': Int64Index([720], dtype='int64'),
#  'B85014': Int64Index([721], dtype='int64'),
#  'B85015': Int64Index([722], dtype='int64'),
#  'B85016': Int64Index([723], dtype='int64'),
#  'B85018': Int64Index([724], dtype='int64'),
#  'B85019': Int64Index([725], dtype='int64'),
#  'B85020': Int64Index([726], dtype='int64'),
#  'B85021': Int64Index([727], dtype='int64'),
#  'B85022': Int64Index([728], dtype='int64'),
#  'B85023': Int64Index([729], dtype='int64'),
#  'B85024': Int64Index([730], dtype='int64'),
#  'B85025': Int64Index([731], dtype='int64'),
#  'B85026': Int64Index([732], dtype='int64'),
#  'B85027': Int64Index([733], dtype='int64'),
#  'B85028': Int64Index([734], dtype='int64'),
#  'B85030': Int64Index([735], dtype='int64'),
#  'B85031': Int64Index([736], dtype='int64'),
#  'B85032': Int64Index([737], dtype='int64'),
#  'B85033': Int64Index([738], dtype='int64'),
#  'B85036': Int64Index([739], dtype='int64'),
#  'B85037': Int64Index([740], dtype='int64'),
#  'B85038': Int64Index([741], dtype='int64'),
#  'B85041': Int64Index([742], dtype='int64'),
#  'B85042': Int64Index([743], dtype='int64'),
#  'B85044': Int64Index([744], dtype='int64'),
#  'B85048': Int64Index([745], dtype='int64'),
#  'B85051': Int64Index([746], dtype='int64'),
#  'B85054': Int64Index([10553, 747], dtype='int64'),
#  'B85055': Int64Index([748], dtype='int64'),
#  'B85058': Int64Index([749], dtype='int64'),
#  'B85059': Int64Index([750], dtype='int64'),
#  'B85060': Int64Index([11919, 10943, 9912, 751], dtype='int64'),
#  'B86672': Int64Index([6985], dtype='int64'),
#  'B86673': Int64Index([7131], dtype='int64'),
#  'B86674': Int64Index([7213], dtype='int64'),
#  'B86675': Int64Index([7228], dtype='int64'),
#  'B86678': Int64Index([7325], dtype='int64'),
#  'B86681': Int64Index([10726], dtype='int64'),
#  'B86682': Int64Index([7410], dtype='int64'),
#  'B86684': Int64Index([7448], dtype='int64'),
#  'B87001': Int64Index([860], dtype='int64'),
#  'B87002': Int64Index([861], dtype='int64'),
#  'B87003': Int64Index([862], dtype='int64'),
#  'B87004': Int64Index([863], dtype='int64'),
#  'B87005': Int64Index([864], dtype='int64'),
#  'B87006': Int64Index([865], dtype='int64'),
#  'B87007': Int64Index([866], dtype='int64'),
#  'B87008': Int64Index([867], dtype='int64'),
#  'B87009': Int64Index([868], dtype='int64'),
#  'B87011': Int64Index([869], dtype='int64'),
#  'B87012': Int64Index([870], dtype='int64'),
#  'B87013': Int64Index([871], dtype='int64'),
#  'B87015': Int64Index([872], dtype='int64'),
#  'B87016': Int64Index([873], dtype='int64'),
#  'B87017': Int64Index([874, 11920], dtype='int64'),
#  'B87018': Int64Index([875], dtype='int64'),
#  'B87019': Int64Index([876], dtype='int64'),
#  'B87020': Int64Index([877], dtype='int64'),
#  'B87021': Int64Index([878], dtype='int64'),
#  'B87022': Int64Index([879], dtype='int64'),
#  'B87023': Int64Index([880], dtype='int64'),
#  'B87025': Int64Index([881], dtype='int64'),
#  'B87026': Int64Index([882], dtype='int64'),
#  'B87027': Int64Index([11065, 883], dtype='int64'),
#  'B87028': Int64Index([884], dtype='int64'),
#  'B87029': Int64Index([885, 11676, 9913, 11921], dtype='int64'),
#  'B87030': Int64Index([886], dtype='int64'),
#  'B87031': Int64Index([887], dtype='int64'),
#  'B87032': Int64Index([888], dtype='int64'),
#  'B87033': Int64Index([889], dtype='int64'),
#  'B87036': Int64Index([890], dtype='int64'),
#  'B87039': Int64Index([891], dtype='int64'),
#  ...}

# %%
practices.loc[9905].reset_index()
# Out:
#        index                 9905
# 0       code               A81001
# 1       name  THE DENSHAM SURGERY
# 2     addr_1    THE HEALTH CENTRE
# 3     addr_2        LAWSON STREET
# 4    borough     STOCKTON-ON-TEES
# 5    village            CLEVELAND
# 6  post_code             TS18 1HU

# %%
by_code.first().reset_index().head()
# Out:
#      code                        name                   addr_1  \
# 0  A81001         THE DENSHAM SURGERY        THE HEALTH CENTRE
# 1  A81002  QUEENS PARK MEDICAL CENTRE  QUEENS PARK MEDICAL CTR
# 2  A81003   VICTORIA MEDICAL PRACTICE           MCKENZIE HOUSE
# 3  A81004      WOODLANDS ROAD SURGERY         6 WOODLANDS ROAD
# 4  A81005          SPRINGWOOD SURGERY       SPRINGWOOD SURGERY
#
#            addr_2           borough    village post_code
# 0   LAWSON STREET  STOCKTON ON TEES  CLEVELAND  TS18 1HU
# 1   FARRER STREET  STOCKTON ON TEES  CLEVELAND  TS18 2AW
# 2  17 KENDAL ROAD        HARTLEPOOL  CLEVELAND  TS25 1QU
# 3          ACKLAM     MIDDLESBROUGH  CLEVELAND   TS1 3BE
# 4    RECTORY LANE       GUISBOROUGH        NaN  TS14 7DJ

# %%
by_code.first().reset_index()[['code', 'post_code']].head()
# Out:
#      code post_code
# 0  A81001  TS18 1HU
# 1  A81002  TS18 2AW
# 2  A81003  TS25 1QU
# 3  A81004   TS1 3BE
# 4  A81005  TS14 7DJ

# %%
# Get a list of unique practices
unique_practices = practices.sort_values('post_code').groupby('code').first().reset_index()[['code', 'post_code']]
unique_practices.head()
# Out:
#      code post_code
# 0  A81001  TS18 1HU
# 1  A81002  TS18 2AW
# 2  A81003  TS25 1QU
# 3  A81004   TS1 3BE
# 4  A81005  TS14 7DJ

# %%
unique_practices = practices[['code', 'post_code']].sort_values(['code', 'post_code']).drop_duplicates(subset='code').reset_index().drop('index', axis=1)
unique_practices.head()
# Out:
#      code post_code
# 0  A81001  TS18 1HU
# 1  A81002  TS18 2AW
# 2  A81003  TS25 1QU
# 3  A81004   TS1 3BE
# 4  A81005  TS14 7DJ

# %%
# Join unique_practices with scripts
joined = scripts.merge(unique_practices,
                      left_on='practice',
                      right_on='code',
                      how='left')

# %%
joined.head()
joined[joined.bnf_name == 'Aspirin Disper_Tab 75mg'].groupby('post_code')['items'].sum().reset_index().tail()
# Out:
#     post_code  items
# 253   WS3 3JP    527
# 254   WS9 8AJ    364
# 255  WV13 2DR    535
# 256  YO11 1UB    323
# 257  YO16 4LZ   1194

# %%
# find the Total items for each bnf_name in each post_code
post_item_totals = joined.groupby(['post_code', 'bnf_name'])['items'].sum().reset_index().sort_values(['post_code', 'items'], ascending=False)
post_item_totals.head()
# Out:
#        post_code                          bnf_name  items
# 576696  YO16 4LZ           Aspirin Disper_Tab 75mg   1194
# 576703  YO16 4LZ             Atorvastatin_Tab 20mg   1122
# 578363  YO16 4LZ           Omeprazole_Cap E/C 20mg   1119
# 577959  YO16 4LZ  Lansoprazole_Cap 30mg (E/C Gran)   1044
# 578443  YO16 4LZ                 Paracet_Tab 500mg   1012

# %%
# Find the most commonly prescriped item in each post code
max_items = post_item_totals.groupby('post_code').first()
max_items.head()
# Out:
#                                      bnf_name  items
# post_code
# B11 4BW    Salbutamol_Inha 100mcg (200 D) CFF    706
# B12 9LP                     Paracet_Tab 500mg    425
# B18 7AL    Salbutamol_Inha 100mcg (200 D) CFF    556
# B21 9RY               Metformin HCl_Tab 500mg   1033
# B23 6DJ      Lansoprazole_Cap 30mg (E/C Gran)    599

# %%
max_items.shape
# Out:
# (259, 2)

# %%
post_code_totals = post_item_totals.groupby('post_code')['items'].sum()
post_code_totals.head()
# Out:
# post_code
# B11 4BW    22731
# B12 9LP    17073
# B18 7AL    20508
# B21 9RY    31027
# B23 6DJ    28011
# Name: items, dtype: int64

# %%
max_items['post_totals'] = post_code_totals
max_items['proportions'] = max_items['items'] / max_items['post_totals']
max_items.head()
# Out:
#                                      bnf_name  items  post_totals  proportions
# post_code
# B11 4BW    Salbutamol_Inha 100mcg (200 D) CFF    706        22731     0.031059
# B12 9LP                     Paracet_Tab 500mg    425        17073     0.024893
# B18 7AL    Salbutamol_Inha 100mcg (200 D) CFF    556        20508     0.027111
# B21 9RY               Metformin HCl_Tab 500mg   1033        31027     0.033294
# B23 6DJ      Lansoprazole_Cap 30mg (E/C Gran)    599        28011     0.021384

# %%
max_items.drop(['items', 'post_totals'], axis=1, inplace=True)
max_items
# Out:
#                                      bnf_name  proportions
# post_code
# B11 4BW    Salbutamol_Inha 100mcg (200 D) CFF     0.031059
# B12 9LP                     Paracet_Tab 500mg     0.024893
# B18 7AL    Salbutamol_Inha 100mcg (200 D) CFF     0.027111
# B21 9RY               Metformin HCl_Tab 500mg     0.033294
# B23 6DJ      Lansoprazole_Cap 30mg (E/C Gran)     0.021384
# ...                                       ...          ...
# WS3 3JP                     Paracet_Tab 500mg     0.021388
# WS9 8AJ                    Amlodipine_Tab 5mg     0.016174
# WV13 2DR   Salbutamol_Inha 100mcg (200 D) CFF     0.022237
# YO11 1UB              Omeprazole_Cap E/C 20mg     0.029712
# YO16 4LZ              Aspirin Disper_Tab 75mg     0.022174
#
# [259 rows x 2 columns]

# %%
items_by_region = list(max_items.itertuples())[:100]
items_by_region
# Out:
# [Pandas(Index='B11 4BW', bnf_name='Salbutamol_Inha 100mcg (200 D) CFF', proportions=0.031058906339360346),
#  Pandas(Index='B12 9LP', bnf_name='Paracet_Tab 500mg', proportions=0.02489310607391788),
#  Pandas(Index='B18 7AL', bnf_name='Salbutamol_Inha 100mcg (200 D) CFF', proportions=0.027111371172225472),
#  Pandas(Index='B21 9RY', bnf_name='Metformin HCl_Tab 500mg', proportions=0.03329358300834757),
#  Pandas(Index='B23 6DJ', bnf_name='Lansoprazole_Cap 30mg (E/C Gran)', proportions=0.021384456106529576),
#  Pandas(Index='B61 0AZ', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.028713318284424378),
#  Pandas(Index='B70 7AW', bnf_name='Paracet_Tab 500mg', proportions=0.025135992162726547),
#  Pandas(Index='B72 1RL', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.020228765092141495),
#  Pandas(Index='B8 1RZ', bnf_name='Metformin HCl_Tab 500mg', proportions=0.021347750961484866),
#  Pandas(Index='B9 5PU', bnf_name='Ventolin_Evohaler 100mcg (200 D)', proportions=0.024826024522257815),
#  Pandas(Index='B90 3LX', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.026965103983080718),
#  Pandas(Index='BA5 1XJ', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.028261290947858113),
#  Pandas(Index='BB11 2DL', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.027381741821396993),
#  Pandas(Index='BB2 1AX', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.03428191046763188),
#  Pandas(Index='BB3 1PY', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.032683395995453356),
#  Pandas(Index='BB4 5SL', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.03747689029549087),
#  Pandas(Index='BB4 7PL', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.027477496877557173),
#  Pandas(Index='BB7 2JG', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.027980664806967485),
#  Pandas(Index='BB8 0JZ', bnf_name='Atorvastatin_Tab 20mg', proportions=0.021515746650768042),
#  Pandas(Index='BB9 7SR', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.02247662283190644),
#  Pandas(Index='BD16 4RP', bnf_name='Lansoprazole_Cap 30mg (E/C Gran)', proportions=0.022780283004198414),
#  Pandas(Index='BD19 5AP', bnf_name='Lansoprazole_Cap 30mg (E/C Gran)', proportions=0.02066220372715759),
#  Pandas(Index='BD3 8QH', bnf_name='Atorvastatin_Tab 40mg', proportions=0.031662850096882154),
#  Pandas(Index='BD4 7SS', bnf_name='Atorvastatin_Tab 40mg', proportions=0.03424183501960914),
#  Pandas(Index='BH14 0DJ', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.02838931332218254),
#  Pandas(Index='BH18 8EE', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.027092370049064923),
#  Pandas(Index='BH23 3AF', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.03546099290780142),
#  Pandas(Index='BL1 3RG', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.03362566656383588),
#  Pandas(Index='BL1 8TU', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.027729220222793487),
#  Pandas(Index='BL2 6NT', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.0271567320510379),
#  Pandas(Index='BL3 5HP', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.03129933420275929),
#  Pandas(Index='BL9 0NJ', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.032037565382786494),
#  Pandas(Index='BL9 0SN', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.03090454288711369),
#  Pandas(Index='BN1 6AG', bnf_name='Lansoprazole_Cap 15mg (E/C Gran)', proportions=0.021755523716160168),
#  Pandas(Index='BN1 8DD', bnf_name='Aspirin Disper_Tab 75mg', proportions=0.021517850460294887),
#  Pandas(Index='BN9 9PW', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.01855317763853853),
#  Pandas(Index='BR2 9GT', bnf_name='Influenza_Vac Inact 0.5ml Pfs', proportions=0.04301700334253742),
#  Pandas(Index='BR3 3FD', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.02865911645197545),
#  Pandas(Index='BS16 3TD', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.03752737892431249),
#  Pandas(Index='BS23 3HQ', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.030246216399367518),
#  Pandas(Index='BS4 1WH', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.029600778967867575),
#  Pandas(Index='BS4 4HU', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.037361354349095155),
#  Pandas(Index='BS48 2XX', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.030207346595095254),
#  Pandas(Index='CA11 8HW', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.027868623340321454),
#  Pandas(Index='CB22 3HU', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.038775726713346066),
#  Pandas(Index='CB9 8HF', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.03391110538046382),
#  Pandas(Index='CH1 4DS', bnf_name='Lansoprazole_Cap 30mg (E/C Gran)', proportions=0.0257736189772634),
#  Pandas(Index='CH41 8DB', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.03327732469980738),
#  Pandas(Index='CH44 5UF', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.03327334826839032),
#  Pandas(Index='CH62 5HS', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.037778835690968446),
#  Pandas(Index='CH62 6EE', bnf_name='Influenza_Vac Inact 0.5ml Pfs', proportions=0.057585894269547),
#  Pandas(Index='CH65 6TG', bnf_name='Lansoprazole_Cap 30mg (E/C Gran)', proportions=0.026067517902474142),
#  Pandas(Index='CH66 3PB', bnf_name='Lansoprazole_Cap 30mg (E/C Gran)', proportions=0.03100619319552803),
#  Pandas(Index='CM18 6LY', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.026445315758738635),
#  Pandas(Index='CR0 0JA', bnf_name='Salbutamol_Inha 100mcg (200 D) CFF', proportions=0.021571724750715768),
#  Pandas(Index='CT11 8AD', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.022307039864291774),
#  Pandas(Index='CV1 4FS', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.028455180531743392),
#  Pandas(Index='CV12 8NQ', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.026444799282852902),
#  Pandas(Index='CV21 2DN', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.04102890311294875),
#  Pandas(Index='CV6 2FL', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.036250663502669624),
#  Pandas(Index='CV6 6DR', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.030544721504009817),
#  Pandas(Index='CW1 3AW', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.03558258199497268),
#  Pandas(Index='CW5 5NX', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.03453647138997736),
#  Pandas(Index='CW7 1AT', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.03666371289322109),
#  Pandas(Index='DA1 2HA', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.019244977658938185),
#  Pandas(Index='DA11 8BZ', bnf_name='Amoxicillin_Cap 500mg', proportions=0.019686834904226208),
#  Pandas(Index='DN16 2AB', bnf_name='Amlodipine_Tab 5mg', proportions=0.019925280199252802),
#  Pandas(Index='DN22 7XF', bnf_name='Simvastatin_Tab 40mg', proportions=0.018624361621210474),
#  Pandas(Index='DN31 3AE', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.03432952436761402),
#  Pandas(Index='DN34 4GB', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.03709507845509909),
#  Pandas(Index='DN6 0HZ', bnf_name='Paracet_Tab 500mg', proportions=0.025764099668243102),
#  Pandas(Index='DN8 4BQ', bnf_name='Lansoprazole_Cap 30mg (E/C Gran)', proportions=0.021703061442945835),
#  Pandas(Index='DY11 6SF', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.021081859317153433),
#  Pandas(Index='E15 4ES', bnf_name='Amlodipine_Tab 10mg', proportions=0.02569068641412703),
#  Pandas(Index='E7 0EP', bnf_name='Metformin HCl_Tab 500mg', proportions=0.037244933982913224),
#  Pandas(Index='FY2 0JG', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.03627638093657511),
#  Pandas(Index='FY4 1TJ', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.04334478808705613),
#  Pandas(Index='FY5 2TZ', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.03540407051009112),
#  Pandas(Index='FY5 3LF', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.035122866094073016),
#  Pandas(Index='FY7 8GU', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.032058079778122195),
#  Pandas(Index='FY8 5DZ', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.02969960416717259),
#  Pandas(Index='GL1 3PX', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.025687801991914012),
#  Pandas(Index='GL20 5GJ', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.02412690753362688),
#  Pandas(Index='GL50 4DP', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.024009042366605605),
#  Pandas(Index='GU9 9QS', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.027052485943893322),
#  Pandas(Index='HA0 4UZ', bnf_name='Metformin HCl_Tab 500mg', proportions=0.027855843941147297),
#  Pandas(Index='HA3 7LT', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.02504635488712953),
#  Pandas(Index='HD6 1AT', bnf_name='Lansoprazole_Cap 30mg (E/C Gran)', proportions=0.021017471736896196),
#  Pandas(Index='HG1 5AR', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.02842489568845619),
#  Pandas(Index='HR1 2JB', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.028529603122966818),
#  Pandas(Index='HR6 8HD', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.027207967812149594),
#  Pandas(Index='HU7 4DW', bnf_name='Salbutamol_Inha 100mcg (200 D) CFF', proportions=0.025607843137254904),
#  Pandas(Index='HU9 2LJ', bnf_name='Lansoprazole_Cap 30mg (E/C Gran)', proportions=0.0243192109011288),
#  Pandas(Index='IG7 4DF', bnf_name='Amlodipine_Tab 5mg', proportions=0.01956475808155504),
#  Pandas(Index='IP22 4WG', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.02851095218241878),
#  Pandas(Index='KT12 3LB', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.01828471919895516),
#  Pandas(Index='KT14 6DH', bnf_name='Amlodipine_Tab 5mg', proportions=0.018667887710894296),
#  Pandas(Index='KT16 8HZ', bnf_name='Amlodipine_Tab 5mg', proportions=0.019319714781268066),
#  Pandas(Index='KT6 6EZ', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.02821316614420063),
#  Pandas(Index='L31 0DJ', bnf_name='Omeprazole_Cap E/C 20mg', proportions=0.029425653739448675)]

# %%
grader.score.dw__items_by_region(items_by_region)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# ## Question 4: script_anomalies
#
# Drug abuse is a source of human and monetary costs in health care. A first step in identifying practitioners that enable drug abuse is to look for practices where commonly abused drugs are prescribed unusually often. Let's try to find practices that prescribe an unusually high amount of opioids. The opioids we'll look for are given in the list below.

# %%
opioids = ['morphine', 'oxycodone', 'methadone', 'fentanyl', 'pethidine', 'buprenorphine', 'propoxyphene', 'codeine']

# %% [markdown]
# These are generic names for drugs, not brand names. Generic drug names can be found using the `'bnf_code'` field in `scripts` along with the `chem` table.. Use the list of opioids provided above along with these fields to make a new field in the `scripts` data that flags whether the row corresponds with a opioid prescription.

# %%
mask = chem['NAME'].str.contains('|'.join(opioids), case=False)
opioid_codes = chem[mask]['CHEM SUB']

# %%
scripts['opioids'] = scripts['bnf_code'].isin(opioid_codes).astype(int)
scripts.head()
# Out:
#   practice   bnf_code                              bnf_name  items   nic  \
# 0   N85639  0106020C0                 Bisacodyl_Tab E/C 5mg      1  0.39
# 1   N85639  0106040M0      Movicol Plain_Paed Pdr Sach 6.9g      1  4.38
# 2   N85639  0301011R0    Salbutamol_Inha 100mcg (200 D) CFF      1  1.50
# 3   N85639  0304010G0  Chlorphenamine Mal_Oral Soln 2mg/5ml      1  2.62
# 4   N85639  0401020K0                      Diazepam_Tab 2mg      1  0.16
#
#    act_cost  quantity  opioids
# 0      0.47        12        0
# 1      4.07        30        0
# 2      1.40         1        0
# 3      2.44       150        0
# 4      0.26         6        0

# %% [markdown]
# Now for each practice calculate the proportion of its prescriptions containing opioids.
#
# **Hint:** Consider the following list: `[0, 1, 1, 0, 0, 0]`. What proportion of the entries are 1s? What is the mean value?

# %%
opioids_per_practice = scripts.groupby('practice')['opioids'].mean()
opioids_per_practice.head()
# Out:
# practice
# A81005    0.033179
# A81007    0.043329
# A81011    0.046556
# A81012    0.042793
# A81017    0.038140
# Name: opioids, dtype: float64

# %%
overall_mean = scripts['opioids'].mean()
overall_mean
# Out:
# 0.03580276471367961

# %%
relative_opioids_per_practice = opioids_per_practice - overall_mean

# %% [markdown]
# How do these proportions compare to the overall opioid prescription rate? Subtract off the proportion of all prescriptions that are opioids from each practice's proportion.

# %%
relative_opioids_per_practice.head()
# Out:
# practice
# A81005   -0.002624
# A81007    0.007526
# A81011    0.010753
# A81012    0.006990
# A81017    0.002337
# Name: opioids, dtype: float64

# %% [markdown]
# Now that we know the difference between each practice's opioid prescription rate and the overall rate, we can identify which practices prescribe opioids at above average or below average rates. However, are the differences from the overall rate important or just random deviations? In other words, are the differences from the overall rate big or small?
#
# To answer this question we have to quantify the difference we would typically expect between a given practice's opioid prescription rate and the overall rate. This quantity is called the **standard error**, and is related to the **standard deviation**, $\sigma$. The standard error in this case is
#
# $$ \frac{\sigma}{\sqrt{n}} $$
#
# where $n$ is the number of prescriptions each practice made. Calculate the standard error for each practice. Then divide `relative_opioids_per_practice` by the standard errors. We'll call the final result `opioid_scores`.

# %% [markdown]
# Recall that the std deviation $({\sigma})$ is the square root of the Variance $(\sqrt{Var})$, that is:
#
# $\sigma = \sqrt{Var}$
#
# Combining this with the equation for **standard error**, we get:
#
# $ \dfrac{\sigma}{\sqrt{n}} = {\dfrac{\sqrt{Var}}{\sqrt{n}}} = \sqrt{\dfrac{Var}{n}}$

# %%
np.sqrt(scripts['opioids'].var() / scripts['practice'].value_counts()).head()
# Out:
# N83028    0.003484
# L83100    0.003513
# D81043    0.003747
# B81008    0.003796
# B81026    0.003835
# Name: practice, dtype: float64

# %%
n_sqrt = np.sqrt(scripts.groupby('practice')['bnf_code'].count().head())
n_sqrt.head()
scripts['practice'].value_counts().sort_index()
# Out:
# A81005    1507
# A81007    1454
# A81011    1568
# A81012    1332
# A81017    2150
#           ...
# Y05570      22
# Y05583      28
# Y05597      18
# Y05660     347
# Y05670      12
# Name: practice, Length: 856, dtype: int64

# %%
standard_error_per_practice = np.sqrt(scripts['opioids'].var() / scripts['practice'].value_counts())
opioid_scores = relative_opioids_per_practice / standard_error_per_practice

# %% [markdown]
# The quantity we have calculated in `opioid_scores` is called a **z-score**:
#
# $$ \frac{\bar{X} - \mu}{\sqrt{\sigma^2/n}} $$
#
# Here $\bar{X}$ corresponds with the proportion for each practice, $\mu$ corresponds with the proportion across all practices, $\sigma^2$ corresponds with the variance of the proportion across all practices, and $n$ is the number of prescriptions made by each practice. Notice $\bar{X}$ and $n$ will be different for each practice, while $\mu$ and $\sigma$ are determined across all prescriptions, and so are the same for every z-score. The z-score is a useful statistical tool used for hypothesis testing, finding outliers, and comparing data about different types of objects or events.
#
# Now that we've calculated this statistic, take the 100 practices with the largest z-score. Return your result as a list of tuples in the form `(practice_name, z-score, number_of_scripts)`. Sort your tuples by z-score in descending order. Note that some practice codes will correspond with multiple names. In this case, use the first match when sorting names alphabetically.

# %%
practices.code.nunique()
# Out:
# 10843

# %%
unique_practices = (practices
                     .sort_values(['code', 'name'])
                     .drop_duplicates(subset=['code'], keep='first'))

# unique_practices

# %%
unique_practices = unique_practices[['code', 'name']]
unique_practices.head()
# Out:
#          code                        name
# 0      A81001         THE DENSHAM SURGERY
# 1      A81002  QUEENS PARK MEDICAL CENTRE
# 2      A81003   VICTORIA MEDICAL PRACTICE
# 11915  A81004     BLUEBELL MEDICAL CENTRE
# 4      A81005          SPRINGWOOD SURGERY

# %%
results = (unique_practices
             .merge(opioid_scores.rename('score'),
                   left_on='code',
                   right_index=True))

results = results.merge(scripts['practice']
                       .value_counts()
                       .rename('count'),
                       left_on='code',
                       right_index=True)

results.sort_values(by='score', ascending=False, inplace=True)

results.drop('code', axis=1, inplace=True)
results.head()
# Out:
#                                  name      score  count
# 7954        NATIONAL ENHANCED SERVICE  11.695818      7
# 8456         OUTREACH SERVICE NH / RH   7.339043      2
# 8783  BRISDOC HEALTHCARE SERVICES OOH   6.150582     60
# 7454           H&R P C SPECIAL SCHEME   5.123032     36
# 9718                   HMR BARDOC OOH   4.958866    321

# %%
anomalies = list(results.itertuples(index=False, name=None))[:100]
anomalies[:2]
# Out:
# [('NATIONAL ENHANCED SERVICE', 11.695817862936027, 7),
#  ('OUTREACH SERVICE NH / RH', 7.339043019238823, 2)]

# %%
unique_practices = ...
# anomalies = [("NATIONAL ENHANCED SERVICE", 11.6958178629, 7)] * 100

# %%
# results.head()

# %%
grader.score.dw__script_anomalies(anomalies)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# ## Question 5: script_growth
#
# Another way to identify anomalies is by comparing current data to historical data. In the case of identifying sites of drug abuse, we might compare a practice's current rate of opioid prescription to their rate 5 or 10 years ago. Unless the nature of the practice has changed, the profile of drugs they prescribe should be relatively stable. We might also want to identify trends through time for business reasons, identifying drugs that are gaining market share. That's what we'll do in this question.
#
# We'll load in beneficiary data from 6 months earlier, June 2016, and calculate the percent growth in prescription rate from June 2016 to January 2017 for each `bnf_name`. We'll return the 50 items with largest growth and the 50 items with the largest shrinkage (i.e. negative percent growth) as a list of tuples sorted by growth rate in descending order in the format `(script_name, growth_rate, raw_2016_count)`. You'll notice that many of the 50 fastest growing items have low counts of prescriptions in 2016. Filter out any items that were prescribed less than 50 times.

# %%
scripts16 = pd.read_csv('./dw-data/201606scripts_sample.csv.gz')

# %%
scripts16.head()
# Out:
#   practice   bnf_code                                 bnf_name  items   nic  \
# 0   N85638  0301011R0   Salamol_Inha 100mcg (200 D) CFF (Teva)      2  2.92
# 1   N85638  0301011R0  Easyhaler_Salbutamol Sulf 200mcg (200D)      1  6.63
# 2   N85638  0301020I0     Ipratrop Brom_Inh Soln 500mcg/2ml Ud      1  1.77
# 3   N85638  0301020I0     Ipratrop Brom_Inh Soln 250mcg/1ml Ud      1  4.47
# 4   N85638  0302000C0        Clenil Modulite_Inha 50mcg (200D)      1  3.70
#
#    act_cost  quantity
# 0      2.73         2
# 1      6.15         1
# 2      1.75        12
# 3      4.15        20
# 4      3.44         1

# %%
# scripts.bnf_name.value_counts() - scripts16.bnf_name.value_counts()

# %%
scripts.groupby('bnf_name')['bnf_name'].count()
# Out:
# bnf_name
# 365 Film 10cm x 12cm VP Adh Film Dress      1
# 365 Non Adherent 10cm x 10cm Pfa Plas Fa    3
# 365 Non Adherent 10cm x 20cm Pfa Plas Fa    1
# 365 Non Woven Island 8cm x 10cm Adh Dres    1
# 365 Transpt Island 5cm x 7.2cm VP Adh Fi    2
#                                            ..
# nSpire PiKo-1 Stnd Range Peak Flow Meter    1
# nSpire Pocket Peak Low Range Peak Flow M    4
# nSpire Pocket Peak Stnd Range Peak Flow     5
# oraNurse_Toothpaste Orig (1450ppm)          4
# palmdoc (Reagent)_Strips                    5
# Name: bnf_name, Length: 13471, dtype: int64

# %%
scripts17_grp_by_bnf_name = scripts.groupby(['bnf_name'])['bnf_name'].count().reset_index(name='count')
scripts17_grp_by_bnf_name = scripts17_grp_by_bnf_name[scripts17_grp_by_bnf_name['count'] > 0]
scripts17_grp_by_bnf_name.head()
# Out:
#                                    bnf_name  count
# 0    365 Film 10cm x 12cm VP Adh Film Dress      1
# 1  365 Non Adherent 10cm x 10cm Pfa Plas Fa      3
# 2  365 Non Adherent 10cm x 20cm Pfa Plas Fa      1
# 3  365 Non Woven Island 8cm x 10cm Adh Dres      1
# 4  365 Transpt Island 5cm x 7.2cm VP Adh Fi      2

# %%
scripts16_grp_by_bnf_name = scripts16.groupby(['bnf_name'])['bnf_name'].count().reset_index(name='count')
scripts16_grp_by_bnf_name = scripts16_grp_by_bnf_name[scripts16_grp_by_bnf_name['count'] >= 50]
scripts16_grp_by_bnf_name.head()
# Out:
#                                     bnf_name  count
# 10  3m Health Care_Cavilon Durable Barrier C    825
# 11  3m Health Care_Cavilon No Sting 1ml Barr    231
# 12  3m Health Care_Cavilon No Sting 3ml Barr    105
# 13   3m Health Care_Cavilon No Sting Barrier    454
# 16         A.S Saliva Orthana Spy 50ml (App)     84

# %%
merged_scripts = pd.merge(scripts16_grp_by_bnf_name, scripts17_grp_by_bnf_name, on='bnf_name', how='inner')

merged_scripts.head()
# Out:
#                                    bnf_name  count_x  count_y
# 0  3m Health Care_Cavilon Durable Barrier C      825      816
# 1  3m Health Care_Cavilon No Sting 1ml Barr      231      223
# 2  3m Health Care_Cavilon No Sting 3ml Barr      105       94
# 3   3m Health Care_Cavilon No Sting Barrier      454      412
# 4         A.S Saliva Orthana Spy 50ml (App)       84      121

# %%
merged_scripts.rename(columns={'count_x': 'raw_2016_count', 'count_y': 'raw_2017_count'}, inplace=True)

merged_scripts.head()
# Out:
#                                    bnf_name  raw_2016_count  raw_2017_count
# 0  3m Health Care_Cavilon Durable Barrier C             825             816
# 1  3m Health Care_Cavilon No Sting 1ml Barr             231             223
# 2  3m Health Care_Cavilon No Sting 3ml Barr             105              94
# 3   3m Health Care_Cavilon No Sting Barrier             454             412
# 4         A.S Saliva Orthana Spy 50ml (App)              84             121

# %% [markdown]
# Calculating change in growth rate...

# %%
merged_scripts['growth_rate'] = (
    (merged_scripts['raw_2017_count'] - merged_scripts['raw_2016_count']) / merged_scripts['raw_2016_count']
)

merged_scripts.head()
# Out:
#                                    bnf_name  raw_2016_count  raw_2017_count  \
# 0  3m Health Care_Cavilon Durable Barrier C             825             816
# 1  3m Health Care_Cavilon No Sting 1ml Barr             231             223
# 2  3m Health Care_Cavilon No Sting 3ml Barr             105              94
# 3   3m Health Care_Cavilon No Sting Barrier             454             412
# 4         A.S Saliva Orthana Spy 50ml (App)              84             121
#
#    growth_rate
# 0    -0.010909
# 1    -0.034632
# 2    -0.104762
# 3    -0.092511
# 4     0.440476

# %%
merged_scripts = merged_scripts.sort_values('growth_rate', ascending=False)
merged_scripts.head()
# Out:
#                                       bnf_name  raw_2016_count  \
# 431            Butec_Transdermal Patch 5mcg/hr              62
# 430           Butec_Transdermal Patch 10mcg/hr              69
# 1409  Fostair NEXThaler_Inh 200mcg/6mcg (120D)              86
# 2612     Pneumococcal_Vac 0.5ml Vl (23 Valent)             193
# 3033  Spiolto Respimat_Inha2.5/2.5mcg(60D)+Dev              52
#
#       raw_2017_count  growth_rate
# 431              277     3.467742
# 430              276     3.000000
# 1409             209     1.430233
# 2612             438     1.269430
# 3033             118     1.269231

# %%
merged_scripts.tail()
# Out:
#                                 bnf_name  raw_2016_count  raw_2017_count  \
# 1623  Hydroxyzine HCl_Oral Soln 10mg/5ml              94               8
# 2471                         Ovysmen_Tab              67               5
# 625                     Climaval_Tab 1mg             136              10
# 627                         Climesse_Tab              69               4
# 2613                Polyalc_Eye Dps 1.4%             272               1
#
#       growth_rate
# 1623    -0.914894
# 2471    -0.925373
# 625     -0.926471
# 627     -0.942029
# 2613    -0.996324

# %% [markdown]
# merge the top 50 (largetst growth) to the last 50 (largest shrinkage)...

# %%
# resp = pd.concat([merge_scripts.head(50),merge_scripts.tail(50)])
result = pd.concat([merged_scripts.head(50), merged_scripts.tail(50)])

result
# Out:
#                                       bnf_name  raw_2016_count  \
# 431            Butec_Transdermal Patch 5mcg/hr              62
# 430           Butec_Transdermal Patch 10mcg/hr              69
# 1409  Fostair NEXThaler_Inh 200mcg/6mcg (120D)              86
# 2612     Pneumococcal_Vac 0.5ml Vl (23 Valent)             193
# 3033  Spiolto Respimat_Inha2.5/2.5mcg(60D)+Dev              52
# ...                                        ...             ...
# 1623        Hydroxyzine HCl_Oral Soln 10mg/5ml              94
# 2471                               Ovysmen_Tab              67
# 625                           Climaval_Tab 1mg             136
# 627                               Climesse_Tab              69
# 2613                      Polyalc_Eye Dps 1.4%             272
#
#       raw_2017_count  growth_rate
# 431              277     3.467742
# 430              276     3.000000
# 1409             209     1.430233
# 2612             438     1.269430
# 3033             118     1.269231
# ...              ...          ...
# 1623               8    -0.914894
# 2471               5    -0.925373
# 625               10    -0.926471
# 627                4    -0.942029
# 2613               1    -0.996324
#
# [100 rows x 4 columns]

# %%
result = result[['bnf_name', 'growth_rate', 'raw_2016_count']]

result.head()
# Out:
#                                       bnf_name  growth_rate  raw_2016_count
# 431            Butec_Transdermal Patch 5mcg/hr     3.467742              62
# 430           Butec_Transdermal Patch 10mcg/hr     3.000000              69
# 1409  Fostair NEXThaler_Inh 200mcg/6mcg (120D)     1.430233              86
# 2612     Pneumococcal_Vac 0.5ml Vl (23 Valent)     1.269430             193
# 3033  Spiolto Respimat_Inha2.5/2.5mcg(60D)+Dev     1.269231              52

# %%
result['raw_2016_count'] = result['raw_2016_count'].astype('float')

result.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                       bnf_name  growth_rate  raw_2016_count
# 431            Butec_Transdermal Patch 5mcg/hr     3.467742            62.0
# 430           Butec_Transdermal Patch 10mcg/hr     3.000000            69.0
# 1409  Fostair NEXThaler_Inh 200mcg/6mcg (120D)     1.430233            86.0
# 2612     Pneumococcal_Vac 0.5ml Vl (23 Valent)     1.269430           193.0
# 3033  Spiolto Respimat_Inha2.5/2.5mcg(60D)+Dev     1.269231            52.0

# %%
# anomalies = list(results.itertuples(index=False, name=None))[:100]
# anomalies[:2]

script_growth = list(result.itertuples())

# len(script_growth)
script_
# Out:
# 100

# %%
# script_growth = [("Butec_Transdermal Patch 5mcg\/hr", 3.4677419355, 62.0)] * 100

# %%
grader.score.dw__script_growth(script_growth)

# %% [markdown]
# ## Question 6: rare_scripts
#
# Does a practice's prescription costs originate from routine care or from reliance on rarely prescribed treatments? Commonplace treatments can carry lower costs than rare treatments because of efficiencies in large-scale production. While some specialist practices can't help but avoid prescribing rare medicines because there are no alternatives, some practices may be prescribing a unnecessary amount of brand-name products when generics are available. Let's identify practices whose costs disproportionately originate from rarely prescribed items.
#
# First we have to identify which `'bnf_code'` are rare. To do this, find the probability $p$ of a prescription having a particular `'bnf_code'` if the `'bnf_code'` was randomly chosen from the unique options in the beneficiary data. We will call a `'bnf_code'` rare if it is prescribed at a rate less than $0.1p$.

# %%
# scripts.bnf_code.value_counts().reset_index(name='bnf_count')

# %%
groupby_bnf_code = scripts.groupby(['bnf_code'])['bnf_code'].count().reset_index(name='bnf_count')
groupby_bnf_code.head()
# Out:
#     bnf_code  bnf_count
# 0  0101010C0         34
# 1  0101010F0          2
# 2  0101010G0        375
# 3  0101010I0         34
# 4  0101010J0         41

# %%
groupby_bnf_code['p'] = groupby_bnf_code['bnf_count']/len(scripts)
groupby_bnf_code.head()
# Out:
#     bnf_code  bnf_count         p
# 0  0101010C0         34  0.000035
# 1  0101010F0          2  0.000002
# 2  0101010G0        375  0.000385
# 3  0101010I0         34  0.000035
# 4  0101010J0         41  0.000042

# %%
# p = ...
# rates = ...
# rare_codes = ...
# scripts['rare'] = ...

# %%
# overall probability:
p = 1 / len(groupby_bnf_code)
p
# Out:
# 0.0005063291139240507

# %% [markdown]
# Add a column with values 1 or 0 for rare or not

# %%
groupby_bnf_code['rare'] = (groupby_bnf_code['p'] < 0.1*p).astype(int)
groupby_bnf_code.head()
# Out:
#     bnf_code  bnf_count         p  rare
# 0  0101010C0         34  0.000035     1
# 1  0101010F0          2  0.000002     1
# 2  0101010G0        375  0.000385     0
# 3  0101010I0         34  0.000035     1
# 4  0101010J0         41  0.000042     1

# %%
# merge scripts and groupby_bnf_code
scripts_rare = scripts.merge(groupby_bnf_code, on='bnf_code', how='left')
scripts_rare.head()
# Out:
#   practice   bnf_code                              bnf_name  items   nic  \
# 0   N85639  0106020C0                 Bisacodyl_Tab E/C 5mg      1  0.39
# 1   N85639  0106040M0      Movicol Plain_Paed Pdr Sach 6.9g      1  4.38
# 2   N85639  0301011R0    Salbutamol_Inha 100mcg (200 D) CFF      1  1.50
# 3   N85639  0304010G0  Chlorphenamine Mal_Oral Soln 2mg/5ml      1  2.62
# 4   N85639  0401020K0                      Diazepam_Tab 2mg      1  0.16
#
#    act_cost  quantity  bnf_count         p  rare
# 0      0.47        12       1035  0.001064     0
# 1      4.07        30       4868  0.005002     0
# 2      1.40         1       6865  0.007054     0
# 3      2.44       150       2141  0.002200     0
# 4      0.26         6       2217  0.002278     0

# %%
# Total cost per practice
total_cost_per_practice = scripts_rare.groupby('practice')['act_cost'].sum().reset_index(name='total_cost')
total_cost_per_practice.head()
# Out:
#   practice  total_cost
# 0   A81005   103840.82
# 1   A81007   113482.49
# 2   A81011   159507.03
# 3   A81012    83296.81
# 4   A81017   232656.17

# %%
# costs from rare
rare_cost = scripts_rare[scripts_rare['rare'] == 1].groupby('practice')['act_cost'].sum().reset_index(name='rare_cost')
rare_cost.head()
# Out:
#   practice  rare_cost
# 0   A81005    1247.83
# 1   A81007     951.06
# 2   A81011     816.02
# 3   A81012    1145.11
# 4   A81017    1712.15

# %%
# Merge rare_cost to total_cost_per_practice and fill empty values with 0
script_cost = total_cost_per_practice.merge(rare_cost, on='practice', how='left').fillna(0)
script_cost.head()
# Out:
#   practice  total_cost  rare_cost
# 0   A81005   103840.82    1247.83
# 1   A81007   113482.49     951.06
# 2   A81011   159507.03     816.02
# 3   A81012    83296.81    1145.11
# 4   A81017   232656.17    1712.15

# %%
script_cost['rare_cost_prop'] = (script_cost['rare_cost'] / script_cost['total_cost'])
script_cost.head()
# Out:
#   practice  total_cost  rare_cost  rare_cost_prop
# 0   A81005   103840.82    1247.83        0.012017
# 1   A81007   113482.49     951.06        0.008381
# 2   A81011   159507.03     816.02        0.005116
# 3   A81012    83296.81    1145.11        0.013747
# 4   A81017   232656.17    1712.15        0.007359

# %%
# total_cost = scripts['act_cost'].sum()
# total_rare_cost = scripts_rare[scripts_rare['rare'] == 1]['act_cost'].sum()
# overall_rare_cost = total_rare_cost / total_cost

# %%
# overall rare cost proportion (the proportion of costs originating from rare treatments across all practices)

total_cost = scripts['act_cost'].sum()
total_rare_cost = scripts_rare[scripts_rare['rare'] == 1]['act_cost'].sum()

overall_rare_cost_prop = total_rare_cost / total_cost
overall_rare_cost_prop
# Out:
# 0.015962901360950386

# %%
"""
calculate relative rare cost proportions by taking the difference of rare_cost_prop and
overall_rare_cost_props
"""
relative_rare_cost_prop = script_cost['rare_cost_prop'] - overall_rare_cost_prop
relative_rare_cost_prop.head()
# Out:
# 0   -0.003946
# 1   -0.007582
# 2   -0.010847
# 3   -0.002216
# 4   -0.008604
# Name: rare_cost_prop, dtype: float64

# %%
# make the relative_rare_cost_prop a column on script_cost
script_cost['relative_rare_cost_prop'] = relative_rare_cost_prop
script_cost.head()
# Out:
#   practice  total_cost  rare_cost  rare_cost_prop  relative_rare_cost_prop
# 0   A81005   103840.82    1247.83        0.012017                -0.003946
# 1   A81007   113482.49     951.06        0.008381                -0.007582
# 2   A81011   159507.03     816.02        0.005116                -0.010847
# 3   A81012    83296.81    1145.11        0.013747                -0.002216
# 4   A81017   232656.17    1712.15        0.007359                -0.008604

# %%
# finding the standard_errors
standard_errors = script_cost['relative_rare_cost_prop'].std()
standard_errors
# Out:
# 0.06050888706745139

# %%
# add a column for z_score
script_cost['z_scores'] = script_cost['relative_rare_cost_prop'] / standard_errors
script_cost.head()
# Out:
#   practice  total_cost  rare_cost  rare_cost_prop  relative_rare_cost_prop  \
# 0   A81005   103840.82    1247.83        0.012017                -0.003946
# 1   A81007   113482.49     951.06        0.008381                -0.007582
# 2   A81011   159507.03     816.02        0.005116                -0.010847
# 3   A81012    83296.81    1145.11        0.013747                -0.002216
# 4   A81017   232656.17    1712.15        0.007359                -0.008604
#
#    z_scores
# 0 -0.065216
# 1 -0.125308
# 2 -0.179263
# 3 -0.036615
# 4 -0.142190

# %%
# find unique alphabetically first name from practices data frame
unique_practices = practices.groupby('code')['name'].min().reset_index()
unique_practices.head()
# Out:
#      code                        name
# 0  A81001         THE DENSHAM SURGERY
# 1  A81002  QUEENS PARK MEDICAL CENTRE
# 2  A81003   VICTORIA MEDICAL PRACTICE
# 3  A81004     BLUEBELL MEDICAL CENTRE
# 4  A81005          SPRINGWOOD SURGERY

# %%
# merge the uniques_practices to the script_cost
df_z_scores = script_cost.merge(unique_practices, how = 'inner', left_on = 'practice', right_on = 'code', sort = False)

df_z_scores.head()
# Out:
#   practice  total_cost  rare_cost  rare_cost_prop  relative_rare_cost_prop  \
# 0   A81005   103840.82    1247.83        0.012017                -0.003946
# 1   A81007   113482.49     951.06        0.008381                -0.007582
# 2   A81011   159507.03     816.02        0.005116                -0.010847
# 3   A81012    83296.81    1145.11        0.013747                -0.002216
# 4   A81017   232656.17    1712.15        0.007359                -0.008604
#
#    z_scores    code                       name
# 0 -0.065216  A81005         SPRINGWOOD SURGERY
# 1 -0.125308  A81007          BANKHOUSE SURGERY
# 2 -0.179263  A81011          CHADWICK PRACTICE
# 3 -0.036615  A81012  WESTBOURNE MEDICAL CENTRE
# 4 -0.142190  A81017        WOODBRIDGE PRACTICE

# %%
# select required fields, sort the values in descending order of z_score and take the first 100 rows

final = (
    df_z_scores[['practice', 'name', 'z_scores']]
    .sort_values('z_scores', ascending=False)
    .head(100)
)

final.head()
# Out:
#     practice                               name   z_scores
# 765   Y03472           CONSULTANT DIABETES TEAM  16.262687
# 831   Y05320     DMC COMMUNITY DERMATOLOGY RBWF  15.128648
# 793   Y04404  OUTPATIENTS JUBILEE HEALTH CENTRE   7.542139
# 766   Y03484   DMC COMMUNITY DERMATOLOGY CLINIC   7.287222
# 794   Y04424                     DMC HEALTHCARE   6.838614

# %%
# convert to tuples
rare_scripts = list(final.itertuples(index=False, name=None))
rare_scripts[:2]
# Out:
# [('Y03472', 'CONSULTANT DIABETES TEAM', 16.262687124655073),
#  ('Y05320', 'DMC COMMUNITY DERMATOLOGY RBWF', 15.128648195416869)]

# %% [markdown]
# Now for each practice, calculate the proportion of costs that originate from prescription of rare treatments (i.e. rare `'bnf_code'`). Use the `'act_cost'` field for this calculation.

# %%
rare_cost_prop = ...

# %% [markdown]
# Now we will calculate a z-score for each practice based on this proportion.
# First take the difference of `rare_cost_prop` and the proportion of costs originating from rare treatments across all practices.

# %%
relative_rare_cost_prop = ...

# %% [markdown]
# Now we will estimate the standard errors (i.e. the denominator of the z-score) by simply taking the standard deviation of this difference.

# %%
standard_errors = ...

# %% [markdown]
# Finally compute the z-scores. Return the practices with the top 100 z-scores in the form `(post_code, practice_name, z-score)`. Note that some practice codes will correspond with multiple names. In this case, use the first match when sorting names alphabetically.

# %%
rare_scores = ...

# %%
# rare_scripts = [("Y03472", "CONSULTANT DIABETES TEAM", 16.2626871247)] * 100

# %%
grader.score.dw__rare_scripts(rare_scripts)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# *Copyright &copy; 2019 The Data Incubator.  All rights reserved.*
